# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Sumit","Keyur","Pranav"],
    "Age" :[34,23,24]
})

# %%
df
# Out:
#      name  Age
# 0   Sumit   34
# 1   Keyur   23
# 2  Pranav   24

# %%
df=pd.read_csv("Orders.csv")
df.head(6)
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5
# 5  FUR-FU-10001487        Furniture   48.9         7    14.2

# %%
df.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
x=df.groupby("region")['sales'].sum()
z=df.groupby("region")['quantity'].sum() + 500
z
# Out:
# region
# Central    580
# East       535
# South      517
# West       564
# Name: quantity, dtype: int64

# %%
import numpy as np

# %%
p=np.arange(len(y))
p1=[j+0.2 for j in p]
plt.bar(p,x,color=c,width=0.2,label ="sales")
plt.bar(p1,z,color='g',width=0.2,label ="quantity")
plt.xticks(p+0.4/2,y,rotation=90)
plt.legend()
plt.show()

# %%
y =['Central','East','South','West']
plt.ylabel("Total Sales",fontsize="10")
plt.xlabel("Regions")
c=["y","b","r","m"]
plt.bar(y,x,color=c,width=0.8,label ="Total",edgecolor='w')
 
plt.legend()
plt.show()

# %%
df.columns= ['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.set_index("order_id").head()
# Out:
#                 order_date   ship_date       ship_mode customer_id region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#                      product_id         category  sales  quantity  profit
# order_id
# CA-2020-152156  FUR-BO-10001798        Furniture  262.0         2    41.9
# CA-2020-152156  FUR-CH-10000454        Furniture  731.9         3   219.6
# CA-2020-138688  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# US-2019-108966  FUR-TA-10000577        Furniture  957.6         5  -383.0
# US-2019-108966  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.reset_index(drop=True).head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
import json
f= open('orders_ETL.json')
data=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 5
#       3 data=json.load(f)
#       4 #data
# ----> 5 df=pd.DataFrame(data.json()['order_id'])
#       6 df
#
# AttributeError: 'list' object has no attribute 'json'

# %%
order_id=[]
order_date=[]
total_amount=[]
quantity=[]
customer_id=[]
name=[]
email=[]
address=[]



for order in data:
    customer_id.append(order['customer']['customer_id'])
    name.append(order['customer']['name'])
    email.append(order['customer']['email'])
    address.append(order['customer']['address'])
    for product in order['products']:
        order_id.append(order['order_id']) 
        order_date.append(order['order_date'])
        total_amount.append(order['total_amount'])
        quantity.append(product['quantity'])

df_order=pd.DataFrame({
    'order_id': order_id,
    'order_date': order_date,
    'Total_amount': total_amount,
    'quantity': quantity
})

df_customer=pd.DataFrame({
    'customer_id': customer_id,
    'name':name,
    'email': email,
    'address': address,

})
df_customer.drop_duplicates(subset=['name','email'], keep='last')  
df_order
# Out:
#     order_id  order_date  Total_amount  quantity
# 0          1  2024-01-10         200.5         2
# 1          1  2024-01-10         200.5         1
# 2          2  2024-01-12         150.0         1
# 3          3  2024-01-12         120.0         2
# 4          4  2024-01-13         300.5         3
# 5          4  2024-01-13         300.5         2
# 6          5  2024-01-14         180.0         1
# 7          5  2024-01-14         180.0         1
# 8          6  2024-01-14         250.0         2
# 9          6  2024-01-14         250.0         2
# 10         6  2024-01-14         250.0         1
# 11         7  2024-01-16         180.0         2
# 12         7  2024-01-16         180.0         1
# 13         8  2024-01-16         230.0         3
# 14         8  2024-01-16         230.0         1
# 15         9  2024-01-17         310.0         2
# 16         9  2024-01-17         310.0         2
# 17        10  2024-01-18         130.0         1
# ...

# %%
df_customer.drop_duplicates(subset=['name','email','customer_id'], keep='last',inplace=True) 
df_customer
# Out:
#     customer_id           name                     email  \
# 1           102     Jane Smith     janesmith@example.com
# 4           104      Bob Brown      bobbrown@example.com
# 5           105          Sania         sania@example.com
# 6           106          Rohit         rohit@example.com
# 7           107     Nina Patel     ninapatel@example.com
# 8           108     Tom Harris     tomharris@example.com
# 9           109        Eva Lee        evalee@example.com
# 10          101       John Doe       johndoe@example.com
# 11          103  Alice Johnson  alicejohnson@example.com
#
#                     address
# 1     456 Oak StSpringfield
# 4   101 Maple StSpringfield
# 5    102 Pine StSpringfield
# 6   103 Cedar StSpringfield
# 7   104 Birch StSpringfield
# 8     105 Oak StSpringfield
# 9     106 Elm StSpringfield
# 10   123 Main StSpringfield
# 11  789 Birch StSpringfield
